# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # load dataset

# %%
df=  pd.read_csv('/kaggle/input/sleep-health-and-lifestyle-dataset/Sleep_health_and_lifestyle_dataset.csv')
df

# %% [markdown]
# # data handling

# %%
df.info()

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
(df.isna().sum()/len(df))*100

# %%
df[df['Sleep Disorder'].isna()]

# %%
df['Sleep Disorder'].unique()

# %% [markdown]
# We cannot drop nan because it describe peaple that doesnot have sleep disorder
# so we replace it with no sleep disorder

# %%
df['Sleep Disorder'].fillna('No Sleep Disorder',inplace=True)

# %%
df.info()

# %% [markdown]
# # Detecting outliers

# %%
numeric_col = ['Age', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'Stress Level', 'Heart Rate', 'Daily Steps']

fig = px.box(df, y=numeric_col, title="Outlier Detection in Numeric Columns")
fig.show()

# %% [markdown]
# Data doesnot have outliers

# %% [markdown]
# # visualization using plotly

# %%
df.head(5)

# %%
fig=px.scatter(df,x='Occupation',y='Sleep Duration',color='Sleep Disorder')
fig.show()

# %% [markdown]
# * engineers have the most sleep so they doesnot suffer from sleep disorder
# * teacheris the most jub suffring from sleep disorder

# %%
fig=px.histogram(df,x='Blood Pressure',y='Heart Rate',color='Sleep Disorder')
fig.show()

# %% [markdown]
# * peaple with heart rate higher than 140/95 suffring from sleep disorder
# * most peaple with insomia have heart rate 130/85
# * most peaple with sleep apena have heart rate 140/95

# %%
fig=px.scatter(df,y='Heart Rate',x='BMI Category',color='Sleep Disorder')
fig.show()

# %% [markdown]
# * the more the heat rate increase the more person suufer in sleeping
# * weight have huge impact on sleeping because most peaple with normal weight doesnot suffer

# %%
fig=px.bar(df,x='Stress Level',y='Quality of Sleep',color='Sleep Disorder')
fig.show()

# %% [markdown]
# higher stress cause less sleep quality

# %%
fig=px.scatter(df,y='Sleep Duration',x='Quality of Sleep',color='Sleep Disorder')
fig.show()

# %% [markdown]
# 7-8 hours of sleep gives higher chance of sleep quality and can prevent sleeping disorder

# %%
fig=px.scatter(df,y='Physical Activity Level',x='Quality of Sleep',color='Sleep Disorder')
fig.show()

# %% [markdown]
# physical activity can help with sleep disorder

# %%
fig=px.scatter(df,y='Age',x='Quality of Sleep',color='Sleep Disorder')
fig.show()

# %%
fig=px.histogram(df,x='Gender',y='Quality of Sleep',color='Sleep Disorder')
fig.show()

# %% [markdown]
# females tend to have higher chance of getting sleep disorder
